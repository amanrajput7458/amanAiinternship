# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
import numpy as np 
import pandas as pd
df = pd.read_csv('wine.csv')
df.head()
y=df['quality']
x=df.drop('quality',axis=1)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=(64,32),activation='relu',max_iter=500)
model.fit(x_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500)

# %%
print(model.score(x_test,y_test))
# Out:
# 0.5875

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = model.predict(x_test)

cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[  0   0   1   0   0   0]
#  [  0   0   9   4   0   0]
#  [  0   0 116  44   4   0]
#  [  0   0  50 107  12   0]
#  [  0   0   2  34  12   0]
#  [  0   0   0   2   3   0]]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1199, 11)
# (400, 11)
# (1199,)
# (400,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(64, input_dim=11, activation='relu'))


model.add(Dense(6, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])   #optimizer task - classification
#optimizer - Adam is an optimization algorithm that can be used instead of the classical stochastic
# gradient descent procedure to update network weights iteratively based on training data.
# It combines the advantages of two other extensions of stochastic gradient descent,
# namely Adaptive Gradient Algorithm (AdaGrad) and Root Mean Square Propagation (RMSProp).
#loss - The loss function used here is 'sparse_categorical_crossentropy',
# which is suitable for multi-class classification problems where the target labels are integers.
# It calculates the cross-entropy loss between the true labels and the predicted probabilities.
#metrics - The model is evaluated using the 'accuracy' metric, which measures the proportion of correctly classified samples.
model.summary()
y_train=y_train-3
#why we are doing this because the quality of wine is in the range of 3-8 and we have to convert it into 0-5 for the model to work properly.
y_test=y_test-3 
#why we are doing this because the quality of wine is in the range of 3-8 and we have to convert it into 0-5 for the model to work properly.

print(np.unique(y_train))
# Out:
# c:\Users\91745\Desktop\2nd year internship\srm\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,158 (4.52 KB)
#  Trainable params: 1,158 (4.52 KB)
#  Non-trainable params: 0 (0.00 B)
# [0 1 2 3 4 5]

# %%
model.fit(x_train,y_train,epochs=100,batch_size=32,validation_data=(x_test,y_test))
#validation_split- 0.2 means 20% of the training data will be used for validation.
#epochs- The model will be trained for 100 epochs, meaning it will iterate over the entire training dataset 100 times.
# Out:
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2010 - loss: 7.2675 - val_accuracy: 0.4200 - val_loss: 3.2825
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4045 - loss: 2.3391 - val_accuracy: 0.4075 - val_loss: 1.8076
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4279 - loss: 1.4549 - val_accuracy: 0.4700 - val_loss: 1.3523
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4954 - loss: 1.2267 - val_accuracy: 0.4675 - val_loss: 1.2344
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5188 - loss: 1.1664 - val_accuracy: 0.4750 - val_loss: 1.1693
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5121 - loss: 1.1403 - val_accuracy: 0.4525 - val_loss: 1.1817
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5246 - loss: 1.1318 - val_accuracy: 0.4625 - val_loss: 1.1569
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5213 - loss: 1.1166 - val_accuracy: 0.4925 - val_loss: 1.1289
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5296 - loss: 1.1170 - val_accuracy: 0.4625 - val_loss: 1.1379
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5179 - loss: 1.1116 - val_accuracy: 0.5150 - val_loss: 1.1122
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5379 - loss: 1.0986 - val_accuracy: 0.4875 - val_loss: 1.1242
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5363 - loss: 1.0936 - val_accuracy: 0.5025 - val_loss: 1.1026
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5388 - loss: 1.0812 - val_accuracy: 0.5200 - val_loss: 1.0998
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5405 - loss: 1.0879 - val_accuracy: 0.4750 - val_loss: 1.1488
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5438 - loss: 1.0804 - val_accuracy: 0.4950 - val_loss: 1.1183
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5455 - loss: 1.0767 - val_accuracy: 0.5050 - val_loss: 1.0975
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5613 - loss: 1.0686 - val_accuracy: 0.5125 - val_loss: 1.0933
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.